# %%
import pandas as pd
import numpy as np

# %%
# Load dataset
sales_df = pd.read_csv('pdv_lineas.csv')
# Display dataframe
sales_df.head()
# Out:
#    id                order_id          create_date  \
# 0   1  LA VICTORIA (QRO)/0001  2022-03-31 23:36:31
# 1   2     ALMACEN CENTRAL0002  2022-04-01 03:53:46
# 2   3      GUERRERO (QRO)0001  2022-04-01 15:58:53
# 3   4      GUERRERO (QRO)0002  2022-04-01 15:59:45
# 4   5      VALLARTA (VTA)0001  2022-04-01 16:03:05
#
#                                    product_id                  create_uid  \
# 0        [19767, 'CHIPS EXPRESS TELCEL "00"']  Emilio Segura De Echavarri
# 1        [19767, 'CHIPS EXPRESS TELCEL "00"']  Emilio Segura De Echavarri
# 2   [22761, 'FDA SAM A03 CAM-ANILLO-10D NGO']         SUC. GUERRERO (QRO)
# 3          [20705, 'FDA IPH 11 SILIC.OR RJO']         SUC. GUERRERO (QRO)
# 4  [25851, 'SOPORTE SISTEMA DE GRAVEDAD STF']         SUC. VALLARTA (VTA)
#
#    qty  price_unit  price_subtotal
# 0  1.0        0.01            0.01
# 1  1.0        0.01            0.01
# 2  1.0      145.69          145.69
# 3  1.0      145.69          145.69
# 4  1.0      102.59          102.59

# %%
# Eliminating rows where create_uid cell, doesn't start with 'SUC'
new_sales_df= sales_df['create_uid'].str.startswith('SUC')
sales_df= sales_df.loc[new_sales_df,['id', 'order_id', 'product_id', 'create_uid',
                                                                'qty', 'price_unit', 'price_subtotal']]
sales_df.head()
# Out:
#    id                 order_id  \
# 2   3       GUERRERO (QRO)0001
# 3   4       GUERRERO (QRO)0002
# 4   5       VALLARTA (VTA)0001
# 5   6  ALLENDE (QRO) (2do)0001
# 6   7  ALLENDE (QRO) (2do)0001
#
#                                           product_id               create_uid  \
# 2          [22761, 'FDA SAM A03 CAM-ANILLO-10D NGO']      SUC. GUERRERO (QRO)
# 3                 [20705, 'FDA IPH 11 SILIC.OR RJO']      SUC. GUERRERO (QRO)
# 4         [25851, 'SOPORTE SISTEMA DE GRAVEDAD STF']      SUC. VALLARTA (VTA)
# 5                   [19227, 'AUDIFONO KIGO VIOLETA']  SUC. ALLENDE (QRO)(2DO)
# 6  [19259, '[AUT117] AUDÍFONOS 1HORA 3.5MM AUT117...  SUC. ALLENDE (QRO)(2DO)
#
#    qty  price_unit  price_subtotal
# 2  1.0      145.69          145.69
# 3  1.0      145.69          145.69
# 4  1.0      102.59          102.59
# 5  1.0       25.00           25.00
# 6  1.0       68.10           68.10

# %%
# Count if there is any 'False' values within our Df
false_df = (sales_df == 'False').sum().sum()
print(f"There are {false_df } 'False' values in the data frame.")
# Out:
# There are 0 'False' values in the data frame.

# %%
new_df = sales_df['product_id'].str.split(', ', n=1, expand=True).rename(columns={0:'Product_ID', 1:'Description'})
new_df['Product_ID'] = new_df['Product_ID'].str.replace("[","")
new_df['Description'] = new_df['Description'].str.replace("[","")
new_df['Description'] = new_df['Description'].str.replace("]","")
new_df['Description'] = new_df['Description'].str.replace("'","")
new_df
# Out:
# /var/folders/lv/mlzsmycd0779gnh3s95csll00000gn/T/ipykernel_2605/1910645473.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   new_df['Product_ID'] = new_df['Product_ID'].str.replace("[","")
# /var/folders/lv/mlzsmycd0779gnh3s95csll00000gn/T/ipykernel_2605/1910645473.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   new_df['Description'] = new_df['Description'].str.replace("[","")
# /var/folders/lv/mlzsmycd0779gnh3s95csll00000gn/T/ipykernel_2605/1910645473.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   new_df['Description'] = new_df['Description'].str.replace("]","")
#        Product_ID                                 Description
# 2           22761              FDA SAM A03 CAM-ANILLO-10D NGO
# 3           20705                     FDA IPH 11 SILIC.OR RJO
# 4           25851             SOPORTE SISTEMA DE GRAVEDAD STF
# 5           19227                       AUDIFONO KIGO VIOLETA
# 6           19259  AUT117 AUDÍFONOS 1HORA 3.5MM AUT117 BLANCO
# ...           ...                                         ...
# 153502      20682          FDA IPH 11 SILIC.ARCOIRIS AZUL/ROS
# 153503      25506             MICA HIDRO TRANSPARENTE CELULAR
# 153504      25526                      MICRO SD-HC 16GB CL-10
# 153505      19673      CARGADOR + CABLE DIMOVIL 3.0 MICRO USB
# 153506      31393                      CORN 3G-GT10 X/X NEGRO
#
# [153421 rows x 2 columns]

# %%
# Creating a new dataframe joining sales_df and new_df
new_sales_df = pd.concat([sales_df,new_df], axis = 1)
new_sales_df = new_sales_df.drop(columns = ['product_id'])
new_sales_df
# Out:
#             id                       order_id                      create_uid  \
# 2            3             GUERRERO (QRO)0001             SUC. GUERRERO (QRO)
# 3            4             GUERRERO (QRO)0002             SUC. GUERRERO (QRO)
# 4            5             VALLARTA (VTA)0001             SUC. VALLARTA (VTA)
# 5            6        ALLENDE (QRO) (2do)0001         SUC. ALLENDE (QRO)(2DO)
# 6            7        ALLENDE (QRO) (2do)0001         SUC. ALLENDE (QRO)(2DO)
# ...        ...                            ...                             ...
# 153502  160925           BOULEVARES (QRO)3192           SUC. BOULEVARES (QRO)
# 153503  160926           BOULEVARES (QRO)3192           SUC. BOULEVARES (QRO)
# 153504  160927  CORREGIDORA 2 (QRO) (2do)5526  SUC. CORREGIDORA 2 (QRO) (2DO)
# 153505  160928         LEON CENTRO (LEON)6015   SUC. LEON CENTRO (LEON) (2DO)
# 153506  160929        ALLENDE (QRO) (2do)8859         SUC. ALLENDE (QRO)(2DO)
#
#         qty  price_unit  price_subtotal Product_ID  \
# 2       1.0  145.690000          145.69      22761
# 3       1.0  145.690000          145.69      20705
# 4       1.0  102.590000          102.59      25851
# 5       1.0   25.000000           25.00      19227
# 6       1.0   68.100000           68.10      19259
# ...     ...         ...             ...        ...
# 153502  1.0  257.758621          257.76      20682
# 153503  1.0  257.760000          257.76      25506
# 153504  1.0   85.340000           85.34      25526
# 153505  1.0  128.448276          128.45      19673
# 153506  1.0  343.970000          343.97      31393
#
#                                        Description
# 2                   FDA SAM A03 CAM-ANILLO-10D NGO
# 3                          FDA IPH 11 SILIC.OR RJO
# 4                  SOPORTE SISTEMA DE GRAVEDAD STF
# 5                            AUDIFONO KIGO VIOLETA
# 6       AUT117 AUDÍFONOS 1HORA 3.5MM AUT117 BLANCO
# ...                                            ...
# 153502          FDA IPH 11 SILIC.ARCOIRIS AZUL/ROS
# 153503             MICA HIDRO TRANSPARENTE CELULAR
# 153504                      MICRO SD-HC 16GB CL-10
# 153505      CARGADOR + CABLE DIMOVIL 3.0 MICRO USB
# 153506                      CORN 3G-GT10 X/X NEGRO
#
# [153421 rows x 8 columns]

# %%
# Reorganize the order of our index - columns
new_sales_df = new_sales_df[['id', 'Product_ID', 'Description', 'order_id',
       'qty', 'create_uid', 'price_unit', 'price_subtotal']]
new_sales_df
# Out:
#             id Product_ID                                 Description  \
# 2            3      22761              FDA SAM A03 CAM-ANILLO-10D NGO
# 3            4      20705                     FDA IPH 11 SILIC.OR RJO
# 4            5      25851             SOPORTE SISTEMA DE GRAVEDAD STF
# 5            6      19227                       AUDIFONO KIGO VIOLETA
# 6            7      19259  AUT117 AUDÍFONOS 1HORA 3.5MM AUT117 BLANCO
# ...        ...        ...                                         ...
# 153502  160925      20682          FDA IPH 11 SILIC.ARCOIRIS AZUL/ROS
# 153503  160926      25506             MICA HIDRO TRANSPARENTE CELULAR
# 153504  160927      25526                      MICRO SD-HC 16GB CL-10
# 153505  160928      19673      CARGADOR + CABLE DIMOVIL 3.0 MICRO USB
# 153506  160929      31393                      CORN 3G-GT10 X/X NEGRO
#
#                              order_id  qty                      create_uid  \
# 2                  GUERRERO (QRO)0001  1.0             SUC. GUERRERO (QRO)
# 3                  GUERRERO (QRO)0002  1.0             SUC. GUERRERO (QRO)
# 4                  VALLARTA (VTA)0001  1.0             SUC. VALLARTA (VTA)
# 5             ALLENDE (QRO) (2do)0001  1.0         SUC. ALLENDE (QRO)(2DO)
# 6             ALLENDE (QRO) (2do)0001  1.0         SUC. ALLENDE (QRO)(2DO)
# ...                               ...  ...                             ...
# 153502           BOULEVARES (QRO)3192  1.0           SUC. BOULEVARES (QRO)
# 153503           BOULEVARES (QRO)3192  1.0           SUC. BOULEVARES (QRO)
# 153504  CORREGIDORA 2 (QRO) (2do)5526  1.0  SUC. CORREGIDORA 2 (QRO) (2DO)
# 153505         LEON CENTRO (LEON)6015  1.0   SUC. LEON CENTRO (LEON) (2DO)
# 153506        ALLENDE (QRO) (2do)8859  1.0         SUC. ALLENDE (QRO)(2DO)
#
#         price_unit  price_subtotal
# 2       145.690000          145.69
# 3       145.690000          145.69
# 4       102.590000          102.59
# 5        25.000000           25.00
# 6        68.100000           68.10
# ...            ...             ...
# 153502  257.758621          257.76
# 153503  257.760000          257.76
# 153504   85.340000           85.34
# 153505  128.448276          128.45
# 153506  343.970000          343.97
#
# [153421 rows x 8 columns]

# %%
# Define a list of words that represent devices
accesories_words = ['MICA', 'MICRO', 'SOPORTE', 'GLASS', 'SIM', 'TARJETA', 'TIEMPO AIRE', 'OTTER' , 
                    'ADAPTADOR DE CORRIENTE', 'USB', 'FLASH DRIVE', 'AUDIFONO', 'AUDÍFONOS', 'FDA',
                   'CARGADOR', 'PORTA', 'CABLE', 'TABLET', 'SD', 'ddd']

# Check which rows contain any of the accesories-related words
is_device = new_sales_df['Description'].str.contains('|'.join(accesories_words))

# Invert the boolean values to select only the rows where no accesories-related words are present
sales_devices_df = new_sales_df[~is_device]
# Displays dataframe with only cellphones
sales_devices_df
# Out:
#             id Product_ID                      Description  \
# 10          11      19436            BLU C5-2019 1/16 GRIS
# 11          12      25586     MOTO E7I-POWER 2/32 AZUL KIT
# 18          19      25957       XIAOMI MI SMART BAND 6 NGO
# 22          23      25990       XIAOMI REDMI-BUDS-3 BLANCO
# 43          44      25740            SAM A03-CORE 2/32 NGO
# ...        ...        ...                              ...
# 153487  160909      26053                ZTE L8 1/32 NEGRO
# 153490  160912      31000  APPLE IPHONE-11 4/64 BLANCO KIT
# 153496  160919      26578             MOTO G41 4/128 NEGRO
# 153498  160921      25533               MOTO E20 2/32 AZUL
# 153506  160929      31393           CORN 3G-GT10 X/X NEGRO
#
#                         order_id  qty                 create_uid  price_unit  \
# 10             LA CRUZ (QRO)0002  1.0         SUC. LA CRUZ (QRO)     1206.03
# 11        HIDALGO 2 (CELAYA)0001  1.0    SUC. HIDALGO 2 (CELAYA)     2654.31
# 18        HIDALGO 2 (CELAYA)0003  1.0    SUC. HIDALGO 2 (CELAYA)      775.00
# 22      CONSTITUYENTES (QRO)0002  1.0  SUC. CONSTITUYENTES (QRO)      861.21
# 43       CORREGIDORA 3 (QRO)0001  1.0   SUC. CORREGIDORA 3 (QRO)     2499.14
# ...                          ...  ...                        ...         ...
# 153487   CORREGIDORA 3 (QRO)5067  1.0   SUC. CORREGIDORA 3 (QRO)     1033.62
# 153490     PLAZA PATIO (QRO)4193  1.0     SUC. PLAZA PATIO (QRO)     9481.90
# 153496         ALLENDE (QRO)1090  1.0         SUC. ALLENDE (QRO)     3275.00
# 153498     PLAZA PATIO (QRO)4194  1.0     SUC. PLAZA PATIO (QRO)     1723.28
# 153506   ALLENDE (QRO) (2do)8859  1.0    SUC. ALLENDE (QRO)(2DO)      343.97
#
#         price_subtotal
# 10             1206.03
# 11             2654.31
# 18              775.00
# 22              861.21
# 43             2499.14
# ...                ...
# 153487         1033.62
# 153490         9481.90
# 153496         3275.00
# 153498         1723.28
# 153506          343.97
#
# [27989 rows x 8 columns]

# %%
# Export the final DataFrame to a CSV file
sales_devices_df.to_csv('ventas_linea_contado_devices.csv', index=False)
